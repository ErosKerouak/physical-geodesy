# %%
import pandas as pd
import numpy as np

# %%
# Caminhos dos arquivos
file_g = "../data/PREPARAÇÃO DOS DADOS_G.xlsx"
file_qg = "../data/PREPARAÇÃO DOS DADOS_QG.xlsx"

# Leitura dos arquivos Excel
df_g = pd.read_excel(file_g)
df_qg = pd.read_excel(file_qg)

# Exibindo as primeiras linhas de cada DataFrame
print(df_g.head())
print(df_qg.head())
# Out:
#    ID  LATITUDE (°) - tide free  LATITUDE GEOCÊNTRICA (°) - tide free  \
# 0   1                -25.516756                            -25.367459
# 1   2                -25.547078                            -25.397654
# 2   3                -25.491400                            -25.342210
# 3   4                -25.438241                            -25.289277
# 4   5                -25.439573                            -25.290603
#
#    LONGITUDE (°) - tide free  h (m) - tide free  H (m) - zero tide  \
# 0                 -49.119866           904.4351           901.0751
# 1                 -49.049065           922.4376           919.3276
# 2                 -48.996752           963.8742           961.0942
# 3                 -49.014173           938.4872           935.6272
# 4                 -49.099058           886.2281           882.9281
#
#    H MDE (m) - zero tide  g (mGal) - mean tide  \
# 0             350.979156           978777.1525
# ...

# %%
df_g
# Out:
#           ID  LATITUDE (°) - tide free  LATITUDE GEOCÊNTRICA (°) - tide free  \
# 0          1                -25.516756                            -25.367459
# 1          2                -25.547078                            -25.397654
# 2          3                -25.491400                            -25.342210
# 3          4                -25.438241                            -25.289277
# 4          5                -25.439573                            -25.290603
# ...      ...                       ...                                   ...
# 30027  63383                -22.780000                            -22.642935
# 30028  63384                -24.240000                            -24.096248
# 30029  63385                -22.735000                            -22.598147
# 30030  63390                -23.931700                            -23.789330
# 30031  63392                -24.185000                            -24.041493
#
# ...

# %%
df_qg
# Out:
#                      ID  LATITUDE (°) - tide free  \
# 0               RENAULT                -25.516756
# 1               SIEMACO                -25.547078
# 2      SANEPAR CARVALHO                -25.491400
# 3              PEDREIRA                -25.438241
# 4       PCA VILA MACEDO                -25.439573
# ...                 ...                       ...
# 63544               NaN                -20.971700
# 63545               NaN                -23.430000
# 63546               NaN                -21.550000
# 63547               NaN                -21.548300
# 63548               NaN                -23.346700
#
#        LATITUDE GEOCÊNTRICA (°) - tide free  LONGITUDE (°) - tide free  \
# 0                                -25.367459                 -49.119866
# 1                                -25.397654                 -49.049065
# 2                                -25.342210                 -48.996752
# 3                                -25.289277                 -49.014173
# ...
