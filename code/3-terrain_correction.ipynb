# %%
import numpy as np
import xarray as xr

# %%
filepath_elevation_ort = '../data/orthometric_mosaic.nc'
elevation_ort = xr.open_dataarray(filepath_elevation_ort)
elevation_ort
# Out:
# <xarray.DataArray (latitude: 6960, longitude: 5760)> Size: 321MB
# [40089600 values with dtype=float64]
# Coordinates:
#   * latitude   (latitude) float64 56kB -39.0 -38.99 -38.99 ... -10.01 -10.0
#   * longitude  (longitude) float64 46kB -60.0 -59.99 -59.99 ... -36.01 -36.0

# %%
lat = - (25 + 26/60 + 54.12695/3600)
long = - (49 + 13/60 + 51.43717/3600)



print(f"Latitude: {lat}°")
print(f"Longitude: {long}°")
# Out:
# Latitude: -25.448368597222224°
# Longitude: -49.230954769444445°

# %%
HP = elevation_ort.sel(latitude=lat, longitude=long, method="nearest").values

print(f"HP: {HP}m")
# Out:
# HP: 916.9657592773438m

# %%
# Calculate resolution in degrees along the longitude and latitude directions
resolution_longitude = np.mean(np.abs(np.diff(elevation_ort.coords['longitude'].values)))
resolution_latitude = np.mean(np.abs(np.diff(elevation_ort.coords['latitude'].values)))
resolution_degrees = np.median([resolution_longitude, resolution_latitude])

print(f"resolution_degrees: {resolution_degrees}°")
# Out:
# resolution_degrees: 0.004166666666666662°

# %%
resolution = (resolution_degrees * 30)*3600

print(f"resolution: {resolution}m")
# Out:
# resolution: 449.9999999999995m

# %%
G = 6.67259*1e-11
rho = 2670

# %%
lat_rad = np.deg2rad(lat)

print(f"latitude em radianos: {lat_rad}")
# Out:
# latitude em radianos: -0.4441578212826585

# %%
gamma_e = 9.7803267715

sin_phi = np.sin(lat_rad)
sin2 = sin_phi ** 2
sin4 = sin_phi ** 4
sin6 = sin_phi ** 6
sin8 = sin_phi ** 8

gamma = (gamma_e * (
        1
        + 0.0052790414 * sin2
        + 0.0000232718 * sin4
        + 0.0000001262 * sin6
        + 0.0000000007 * sin8
    ))*1e5


print(gamma)
# Out:
# 978986.7640474108

# %%
cte1 = ((G*rho/2) * (resolution**2))*1e5
cte2 = ((3*G*rho/8) * (resolution**2))*1e5

print(f"cte1: {cte1} mGal")
print(f"cte2: {cte2} mGal")
# Out:
# cte1: 1803.8512991249956 mGal
# cte2: 1352.888474343747 mGal

# %%
for i in range(elevation_ort.sizes['northing']):
    for j in range(elevation_ort.sizes['easting']):
        valor = seu_dataarray.isel(northing=i, easting=j).item()
        x = seu_dataarray.easting[j].item()
        y = seu_dataarray.northing[i].item()
        # Faça algo com (x, y, valor)

# %%
#0,1171085003497657 mGal

# %%
xr.apply_ufunc(
    func,                  # sua função (numpy, scipy, ou customizada)
    *args,                 # argumentos (DataArrays, Datasets, scalars, etc)
    input_core_dims=[...], # dimensões que a função espera em cada argumento
    output_core_dims=[...],# dimensões que a função retorna
    vectorize=False,       # True se quiser aplicar elemento a elemento
    dask='parallelized',   # para usar com Dask
    output_dtypes=[...]    # tipo de saída, necessário se usar Dask
)

# %%
moho_depth = xr.apply_ufunc(
        moho_cell_calculation,
        basement,
        *layers,
        vectorize=True,
        dask='parallelized',
        output_dtypes=[float]
    )
